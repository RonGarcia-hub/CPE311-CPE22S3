# %% [markdown]
# <a href="https://colab.research.google.com/github/RonGarcia-hub/CPE311-CPE22S3/blob/main/Hands_on_Activity_1_1_Garcia%2C_Ron.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Hands-on Activity 1.1 | Optimization and Knapsack Problem

# %% [markdown]
# #### Objective(s):
#
# This activity aims to demonstrate how to apply  greedy and brute force algorithms to solve optimization problems

# %% [markdown]
# #### Intended Learning Outcomes (ILOs):
# * Demonstrate how to solve knapsacks problems using greedy algorithm
# * Demonstrate how to  solve knapsacks problems using brute force algorithm

# %% [markdown]
# #### Resources:
# * Jupyter Notebook

# %% [markdown]
# #### Procedures:

# %% [markdown]
# 1. Create a Food class that defines the following:
# * name of the food
# * value of the food
# * calories of the food
#
# 2. Create the following methods inside the Food class:
# * A method that returns the value of the food
# * A method that returns the cost of the food
# * A method that calculates the density of the food (Value / Cost)
# * A method that returns a string to display the name, value and calories of the food

# %%
class Food(object):
    def __init__(self, n, v, w):
        # Make the variables private
        self.name = n
        self.value = v
        self.calories = w
    def getValue(self):
        return self.value
    def getCost(self):
        return self.calories
    def density(self):
        return self.getValue()/self.getCost()
    def __str__(self):
        return self.name + ': <' + str(self.value)+ ', ' + str(self.calories) + '>'

# %% [markdown]
# 3. Create a buildMenu method that builds the name, value and calories of the food

# %%
def buildMenu(names, values, calories):
    menu = []
    for i in range(len(values)):
        menu.append(Food(names[i], values[i],calories[i]))
    return menu

# %% [markdown]
# 4. Create a method greedy to return total value and cost of added food based on the desired maximum cost

# %%
def greedy(items, maxCost, keyFunction):
    """Assumes items a list, maxCost >= 0,         keyFunction maps elements of items to numbers"""
    itemsCopy = sorted(items, key = keyFunction,
                       reverse = True)
    result = []
    totalValue, totalCost = 0.0, 0.0
    for i in range(len(itemsCopy)):
        if (totalCost+itemsCopy[i].getCost()) <= maxCost:
            result.append(itemsCopy[i])
            totalCost += itemsCopy[i].getCost()
            totalValue += itemsCopy[i].getValue()
    return (result, totalValue)

# %% [markdown]
# 5. Create a testGreedy method to test the greedy method

# %%
def testGreedy(items, constraint, keyFunction):
    taken, val = greedy(items, constraint, keyFunction)
    print('Total value of items taken =', val)
    for item in taken:
        print('   ', item)

# %%
def testGreedys(foods, maxUnits):
    print('Use greedy by value to allocate', maxUnits,          'calories')
    testGreedy(foods, maxUnits, Food.getValue)
    print('\nUse greedy by cost to allocate', maxUnits,          'calories')
    testGreedy(foods, maxUnits, lambda x: 1/Food.getCost(x))
    print('\nUse greedy by density to allocate', maxUnits,          'calories')
    testGreedy(foods, maxUnits, Food.density)

# %% [markdown]
# 6. Create arrays of food name, values and calories
# 7. Call the buildMenu to create menu for food
# 8. Use testGreedys method to pick food according to the desired calories

# %%
names = ['wine', 'beer', 'pizza', 'burger', 'fries','cola', 'apple', 'donut', 'cake']
values = [89,90,95,100,90,79,50,10]
calories = [123,154,258,354,365,150,95,195]
foods = buildMenu(names, values, calories)
testGreedys(foods, 2000)
# Out:
# Use greedy by value to allocate 2000 calories
# Total value of items taken = 603.0
#     burger: <100, 354>
#     pizza: <95, 258>
#     beer: <90, 154>
#     fries: <90, 365>
#     wine: <89, 123>
#     cola: <79, 150>
#     apple: <50, 95>
#     donut: <10, 195>
#
# Use greedy by cost to allocate 2000 calories
# Total value of items taken = 603.0
#     apple: <50, 95>
#     wine: <89, 123>
#     cola: <79, 150>
#     beer: <90, 154>
#     donut: <10, 195>
#     pizza: <95, 258>
#     burger: <100, 354>
#     fries: <90, 365>
#
# Use greedy by density to allocate 2000 calories
# Total value of items taken = 603.0
#     wine: <89, 123>
#     beer: <90, 154>
#     cola: <79, 150>
#     apple: <50, 95>
#     pizza: <95, 258>
#     burger: <100, 354>
#     fries: <90, 365>
#     donut: <10, 195>

# %% [markdown]
# Task 1: Change the maxUnits to 100

# %%
#type your code here maxunits to 100
names = ['wine', 'beer', 'pizza', 'burger', 'fries','cola', 'apple', 'donut', 'cake']
values = [89,90,95,100,90,79,50,10]
calories = [123,154,258,354,365,150,95,195]
foods = buildMenu(names, values, calories)
testGreedys(foods,100)
# Out:
# Use greedy by value to allocate 100 calories
# Total value of items taken = 50.0
#     apple: <50, 95>
#
# Use greedy by cost to allocate 100 calories
# Total value of items taken = 50.0
#     apple: <50, 95>
#
# Use greedy by density to allocate 100 calories
# Total value of items taken = 50.0
#     apple: <50, 95>

# %% [markdown]
# Task 2: Modify codes to add additional weight (criterion) to select food items.

# %%
# type your code here
class Food(object):
    def __init__(self, n, v, w,x):
        # Make the variables private
        self.name = n
        self.value = v
        self.calories = w
        self.weight = x
    def getValue(self):
        return self.value
    def getCost(self):
        return self.calories
    def density(self):
        return self.getValue()/self.getCost()
    def getWeight(self):
        return self.weight
    def __str__(self):
        return self.name + ': <' + str(self.value)+ ', ' + str(self.calories) + ', ' + str(self.weight)+ '>'

# %%
def buildMenu(names, values, calories, weight):
    menu = []
    for i in range(len(values)):
        menu.append(Food(names[i], values[i],calories[i], weight[i]))
    return menu

# %%
def greedy(items, maxCost, keyFunction):
    """Assumes items a list, maxCost >= 0,         keyFunction maps elements of items to numbers"""
    itemsCopy = sorted(items, key = keyFunction,
                       reverse = True)
    result = []
    totalValue, totalCost = 0.0, 0.0
    for i in range(len(itemsCopy)):
        if (totalCost+itemsCopy[i].getCost()) <= maxCost:
            result.append(itemsCopy[i])
            totalCost += itemsCopy[i].getCost()
            totalValue += itemsCopy[i].getValue()
    return (result, totalValue)

# %%
def testGreedys(foods, maxUnits):
    print('Use greedy by value to allocate', maxUnits,          'calories')
    testGreedy(foods, maxUnits, Food.getValue)
    print('\nUse greedy by cost to allocate', maxUnits,          'calories')
    testGreedy(foods, maxUnits, lambda x: 1/Food.getCost(x))
    print('\nUse greedy by density to allocate', maxUnits,          'calories')
    testGreedy(foods, maxUnits, Food.density)
    print('\nUse greedy by weight to allocate', maxUnits,          'calories')
    testGreedy(foods, maxUnits, Food.getWeight)

# %% [markdown]
# Task 3: Test your modified code to test the greedy algorithm to select food items with your additional weight.

# %%
# type your code here
names = ['wine', 'beer', 'pizza', 'burger', 'fries','cola', 'apple', 'donut', 'cake']
values = [89,90,95,100,90,79,50,10]
calories = [123,154,258,354,365,150,95,195]
weight = [10,15,50,30,20,10,5,15,60]
foods = buildMenu(names, values, calories, weight)
testGreedys(foods, 2000)
# Out:
# Use greedy by value to allocate 2000 calories
# Total value of items taken = 603.0
#     burger: <100, 354, 30>
#     pizza: <95, 258, 50>
#     beer: <90, 154, 15>
#     fries: <90, 365, 20>
#     wine: <89, 123, 10>
#     cola: <79, 150, 10>
#     apple: <50, 95, 5>
#     donut: <10, 195, 15>
#
# Use greedy by cost to allocate 2000 calories
# Total value of items taken = 603.0
#     apple: <50, 95, 5>
#     wine: <89, 123, 10>
#     cola: <79, 150, 10>
#     beer: <90, 154, 15>
#     donut: <10, 195, 15>
#     pizza: <95, 258, 50>
#     burger: <100, 354, 30>
#     fries: <90, 365, 20>
#
# Use greedy by density to allocate 2000 calories
# Total value of items taken = 603.0
#     wine: <89, 123, 10>
#     beer: <90, 154, 15>
#     cola: <79, 150, 10>
#     apple: <50, 95, 5>
#     pizza: <95, 258, 50>
#     burger: <100, 354, 30>
#     fries: <90, 365, 20>
#     donut: <10, 195, 15>
#
# Use greedy by weight to allocate 2000 calories
# Total value of items taken = 603.0
#     pizza: <95, 258, 50>
#     burger: <100, 354, 30>
#     fries: <90, 365, 20>
#     beer: <90, 154, 15>
#     donut: <10, 195, 15>
#     wine: <89, 123, 10>
#     cola: <79, 150, 10>
#     apple: <50, 95, 5>

# %% [markdown]
# 9. Create method to use  Bruteforce algorithm instead of greedy algorithm

# %%
def maxVal(toConsider, avail):
    """Assumes toConsider a list of items, avail a weight
       Returns a tuple of the total value of a solution to the
         0/1 knapsack problem and the items of that solution"""
    if toConsider == [] or avail == 0:
        result = (0, ())
    elif toConsider[0].getCost() > avail:
        #Explore right branch only
        result = maxVal(toConsider[1:], avail)
    else:
        nextItem = toConsider[0]
        #Explore left branch
        withVal, withToTake = maxVal(toConsider[1:],
                                     avail - nextItem.getCost())
        withVal += nextItem.getValue()
        #Explore right branch
        withoutVal, withoutToTake = maxVal(toConsider[1:], avail)
        #Choose better branch
        if withVal > withoutVal:
            result = (withVal, withToTake + (nextItem,))
        else:
            result = (withoutVal, withoutToTake)
    return result

# %%
def testMaxVal(foods, maxUnits, printItems = True):
    print('Use search tree to allocate', maxUnits,
          'calories')
    val, taken = maxVal(foods, maxUnits)
    print('Total costs of foods taken =', val)
    if printItems:
        for item in taken:
            print('   ', item)

# %%
names = ['wine', 'beer', 'pizza', 'burger', 'fries','cola', 'apple', 'donut', 'cake']
values = [89,90,95,100,90,79,50,10]
calories = [123,154,258,354,365,150,95,195]
foods = buildMenu(names, values, calories)
testMaxVal(foods, 2400)
# Out:
# Use search tree to allocate 2400 calories
# Total costs of foods taken = 603
#     donut: <10, 195>
#     apple: <50, 95>
#     cola: <79, 150>
#     fries: <90, 365>
#     burger: <100, 354>
#     pizza: <95, 258>
#     beer: <90, 154>
#     wine: <89, 123>

# %% [markdown]
# #### Supplementary Activity:

# %% [markdown]
# * Choose a real-world problem that solves knapsacks problem
# * Use the greedy and brute force algorithm to solve knapsacks problem

# %%
class Supply(object):
  def __init__(self, n, v, w, x):
    self.name = n
    self.heal = v
    self.weight = w
    self.space = x
  def getHeal(self): return self.heal
  def getWeight(self): return self.weight
  def value(self): return self.getHeal()/self.getWeight()
  def getSpace(self): return self.space
  def __str__(self): return self.name + ': <' + str(self.heal)+ ', ' + str(self.weight) + ', ' + str(self.space)+ '>'

# %%
def buildMenu(names, heal, weight, space):
    menu = []
    for i in range(len(heal)):
        menu.append(Supply(names[i], heal[i],weight[i], space[i]))
    return menu

# %%
def greedy(items, maxWeight, keyFunction):

    itemsCopy = sorted(items, key = keyFunction,
                       reverse = True)
    result = []
    totalValue, totalCost = 0.0, 0.0
    for i in range(len(itemsCopy)):
        if (totalCost+itemsCopy[i].getWeight()) <= maxWeight:
            result.append(itemsCopy[i])
            totalCost += itemsCopy[i].getWeight()
            totalValue += itemsCopy[i].getHeal()
    return (result, totalValue)

# %%
def testGreedy(Supply, constraint, keyFunction):
    taken, val = greedy(Supply, constraint, keyFunction)
    print('Total value of items taken =', val)
    for item in taken:
        print('   ', item)

# %%
def testGreedys(items, maxWeight):
    print('Use greedy by heal to allocate', maxWeight, 'weight')
    testGreedy(items, maxWeight, Supply.getHeal)
    print('\nUse greedy by weight to allocate', maxWeight, 'weight')
    testGreedy(items, maxWeight, lambda x: 1 / x.getWeight())
    print('\nUse greedy by value to allocate', maxWeight, 'weight')
    testGreedy(items, maxWeight, Supply.value)
    print('\nUse greedy by space to allocate', maxWeight, 'weight')
    testGreedy(items, maxWeight, Supply.getSpace)

# %%
names = ['bandage', 'First Aid Kit', 'Band Aid', 'Food', 'Medicine',
         'Sleeping Bag', 'Crutches', 'Biogesic']
heal = [30,50,15,20,80,10,5,15]
weight = [20,30,5,15,10,25,8,2]
space = [10,20,5,12,8,25,7,2]

supplies = buildMenu(names, heal, weight, space)
testGreedys(supplies, 200)
# Out:
# Use greedy by heal to allocate 200 weight
# Total value of items taken = 225.0
#     Medicine: <80, 10, 8>
#     First Aid Kit: <50, 30, 20>
#     bandage: <30, 20, 10>
#     Food: <20, 15, 12>
#     Band Aid: <15, 5, 5>
#     Biogesic: <15, 2, 2>
#     Sleeping Bag: <10, 25, 25>
#     Crutches: <5, 8, 7>
#
# Use greedy by weight to allocate 200 weight
# Total value of items taken = 225.0
#     Biogesic: <15, 2, 2>
#     Band Aid: <15, 5, 5>
#     Crutches: <5, 8, 7>
#     Medicine: <80, 10, 8>
#     Food: <20, 15, 12>
#     bandage: <30, 20, 10>
#     Sleeping Bag: <10, 25, 25>
#     First Aid Kit: <50, 30, 20>
#
# Use greedy by value to allocate 200 weight
# Total value of items taken = 225.0
#     Medicine: <80, 10, 8>
#     Biogesic: <15, 2, 2>
#     Band Aid: <15, 5, 5>
#     First Aid Kit: <50, 30, 20>
#     bandage: <30, 20, 10>
#     Food: <20, 15, 12>
#     Crutches: <5, 8, 7>
#     Sleeping Bag: <10, 25, 25>
#
# Use greedy by space to allocate 200 weight
# Total value of items taken = 225.0
#     Sleeping Bag: <10, 25, 25>
#     First Aid Kit: <50, 30, 20>
#     Food: <20, 15, 12>
#     bandage: <30, 20, 10>
#     Medicine: <80, 10, 8>
#     Crutches: <5, 8, 7>
#     Band Aid: <15, 5, 5>
#     Biogesic: <15, 2, 2>

# %% [markdown]
# #### Conclusion:

# %% [markdown]
# #type your conclusion here

# %% [markdown]
# I have concluded that setting up the variables and values that I need to use takes the longest, after that I need to come up with a solid logic that could represent my solution to the problem in order for the program to come up with the most optimized solution within the constraints I placed and with the objectives that I have set up. All in all I think that the greedy method and the brute force method could be good for problems that can be solved with simple solutions.
